# %%
pip install -U matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ventas = pd.read_csv("ventas_mensuales.csv", parse_dates=["mes"])

fig, ax = plt.subplots()
ax.bar(ventas["mes"].dt.strftime("%b"), ventas["ingresos"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 5))

# Creamos una lista de colores gris para todas las barras, y un color
# distinto solo para la barra que queremos resaltar.
colores = ["#B0B0B0"] * len(ventas)
mes_pico = ventas["ingresos"].idxmax()
colores[mes_pico] = "#2E86AB"

ax.bar(ventas["mes"].dt.strftime("%b"), ventas["ingresos"], color=colores)

ax.set_title("Diciembre concentró el 22% de los ingresos del año", loc="left", fontsize=13, weight="bold")
ax.set_ylabel("Ingresos (ARS)")
ax.spines[["top", "right"]].set_visible(False)  # quitamos los bordes que no aportan información
ax.yaxis.grid(True, alpha=0.3)
ax.set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(8, 5))

sns.barplot(
    data=ventas_por_categoria,
    x="ingresos",
    y="categoria",
    color="#2E86AB",
    ax=ax
)

ax.set_title(
    "Electrónica lidera con más del doble que la segunda categoría",
    loc="left",
    weight="bold"
)

ax.set_xlabel("Ingresos")
ax.set_ylabel("Categoría")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))

plt.pie(
    ventas_por_categoria["ingresos"],
    labels=ventas_por_categoria["categoria"],
    autopct="%1.1f%%",
    startangle=90
)

plt.title(
    "Distribución de ingresos por categoría",
    loc="left",
    weight="bold"
)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

variacion_mensual = pd.read_csv("variacion_mensual.csv")

print(variacion_mensual.columns)
print(variacion_mensual.head())
# Out:
# Index(['mes', 'variacion_pct'], dtype='str')
#    mes  variacion_pct
# 0  Jan            2.8
# 1  Feb           -5.4
# 2  Mar            1.8
# 3  Apr            7.6
# 4  May           -8.8

# %%
import matplotlib.pyplot as plt

# Colores según el signo de la variación
colores = [
    "#2E86AB" if valor >= 0 else "#D1495B"
    for valor in variacion_mensual["variacion_pct"]
]

fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(
    variacion_mensual["mes"],
    variacion_mensual["variacion_pct"],
    color=colores
)

# Línea de referencia en cero
ax.axhline(0, color="black", linewidth=1)

ax.set_title(
    "Variación porcentual mes a mes",
    loc="left",
    weight="bold"
)

ax.set_xlabel("Mes")
ax.set_ylabel("Variación (%)")

plt.tight_layout()
plt.show()
